# %%
pip install -qU "langchain[anthropic]"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
import os

if not os.environ.get("ANTHROPIC_API_KEY"):
  os.environ["ANTHROPIC_API_KEY"] = getpass.getpass("Enter API key for Anthropic: ")

from langchain.chat_models import init_chat_model

model = init_chat_model("claude-3-5-sonnet-latest", model_provider="anthropic")

# %%
model.invoke("Hello, world!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.invoke("Hello, world!")
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:307, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     296 def invoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)
#     302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
#     305     return cast(
#     306         ChatGeneration,
# --> 307         self.generate_prompt(
#     308             [self._convert_input(input)],
#     309             stop=stop,
#     310             callbacks=config.get("callbacks"),
#     311             tags=config.get("tags"),
#     312             metadata=config.get("metadata"),
#     313             run_name=config.get("run_name"),
#     314             run_id=config.pop("run_id", None),
#     315             **kwargs,
#     316         ).generations[0][0],
#     317     ).message
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:843, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     835 def generate_prompt(
#     836     self,
#     837     prompts: list[PromptValue],
#    (...)
#     840     **kwargs: Any,
#     841 ) -> LLMResult:
#     842     prompt_messages = [p.to_messages() for p in prompts]
# --> 843     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:683, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     680 for i, m in enumerate(messages):
#     681     try:
#     682         results.append(
# --> 683             self._generate_with_cache(
#     684                 m,
#     685                 stop=stop,
#     686                 run_manager=run_managers[i] if run_managers else None,
#     687                 **kwargs,
#     688             )
#     689         )
#     690     except BaseException as e:
#     691         if run_managers:
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:908, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     906 else:
#     907     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 908         result = self._generate(
#     909             messages, stop=stop, run_manager=run_manager, **kwargs
#     910         )
#     911     else:
#     912         result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/langchain_anthropic/chat_models.py:849, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#     847     return generate_from_stream(stream_iter)
#     848 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# --> 849 data = self._client.messages.create(**payload)
#     850 return self._format_output(data, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/resources/messages/messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     946 if model in DEPRECATED_MODELS:
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/_base_client.py:1330, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1316 def post(
#    1317     self,
#    1318     path: str,
#    (...)
#    1325     stream_cls: type[_StreamT] | None = None,
#    1326 ) -> ResponseT | _StreamT:
#    1327     opts = FinalRequestOptions.construct(
#    1328         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1329     )
# -> 1330     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/_base_client.py:1007, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1004 else:
#    1005     retries_taken = 0
# -> 1007 return self._request(
#    1008     cast_to=cast_to,
#    1009     options=options,
#    1010     stream=stream,
#    1011     stream_cls=stream_cls,
#    1012     retries_taken=retries_taken,
#    1013 )
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/_base_client.py:1033, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1030 options = self._prepare_options(options)
#    1032 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# -> 1033 request = self._build_request(options, retries_taken=retries_taken)
#    1034 self._prepare_request(request)
#    1036 kwargs: HttpxSendArgs = {}
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/_base_client.py:481, in BaseClient._build_request(self, options, retries_taken)
#     478     else:
#     479         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 481 headers = self._build_headers(options, retries_taken=retries_taken)
#     482 params = _merge_mappings(self.default_query, options.params)
#     483 content_type = headers.get("Content-Type")
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/_base_client.py:422, in BaseClient._build_headers(self, options, retries_taken)
#     412 custom_headers = options.headers or {}
#     413 headers_dict = _merge_mappings(
#     414     {
#     415         "x-stainless-timeout": str(options.timeout.read)
#    (...)
#     420     custom_headers,
#     421 )
# --> 422 self._validate_headers(headers_dict, custom_headers)
#     424 # headers are case-insensitive while dictionaries are not.
#     425 headers = httpx.Headers(headers_dict)
#
# File /opt/homebrew/lib/python3.11/site-packages/anthropic/_client.py:180, in Anthropic._validate_headers(self, headers, custom_headers)
#     177 if isinstance(custom_headers.get("Authorization"), Omit):
#     178     return
# --> 180 raise TypeError(
#     181     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     182 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
